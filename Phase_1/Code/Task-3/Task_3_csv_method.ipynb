# %%
import os
import av
import numpy as np
import cv2
import csv

grid_size = 4  # How many rows and columns we're splitting the frame into
bin_count = 12  # Number of color shades we're counting in each histogram

video_folder = 'Target_video/Sword'

def process_videos_in_folder(folder_path):
    parent_folder = os.path.abspath(os.path.join(folder_path, os.pardir))
    
    results_folder = os.path.join(parent_folder, "hello sample")  # Where the results are saved
    os.makedirs(results_folder, exist_ok=True)  # Create the folder if it's not there
    
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith((".avi")):  # We only want video files
                video_path = os.path.join(root, file)
                video_name = os.path.splitext(os.path.relpath(video_path, folder_path))[0]
                analyze_video(video_path, video_name, results_folder)

def extract_key_frames(video_path):
    try:
        video = av.open(video_path)
        all_frames = [frame for frame in video.decode(video=0)]
        key_frames = [all_frames[0], all_frames[len(all_frames) // 2], all_frames[-1]] # get 1st frame,middle frame, and the last frame
        return key_frames
    except UnicodeDecodeError as e:
        print(f"Oops! Can't read this file: {video_path}. Error: {e}")
        return None
    except Exception as e:
        print(f"Something went wrong with {video_path}. Error: {e}")
        return None

def analyze_video(video_path, video_name, results_folder):
    key_frames = extract_key_frames(video_path)
    if key_frames is None:
        print(f"Skipping {video_path}. Couldn't get the frames we needed.")  # User-friendly skip message
        return
    video_results_folder = os.path.join(results_folder, f'{video_name}_output')
    os.makedirs(video_results_folder, exist_ok=True)
    for frame_number, frame in enumerate(key_frames, 1):
        create_color_histogram(frame, grid_size, bin_count, frame_number, video_results_folder)

def create_color_histogram(frame, grid_size, bin_count, frame_number, output_folder):
    try:
        image = np.array(frame.to_image())  # Convert frame to image
    except Exception as e:
        print(f"Couldn't convert frame to image. Skipping.")
        return None
    
    height, width, _ = image.shape
    cell_height, cell_width = height // grid_size, width // grid_size
    
    all_histograms = []
    for row in range(grid_size):
        for col in range(grid_size):
            cell = image[row * cell_height:(row + 1) * cell_height, 
                         col * cell_width:(col + 1) * cell_width]
            red_hist = cv2.calcHist([cell], [0], None, [bin_count], [0, 256]).flatten()
            green_hist = cv2.calcHist([cell], [1], None, [bin_count], [0, 256]).flatten() # Count the colors in each grid block
            blue_hist = cv2.calcHist([cell], [2], None, [bin_count], [0, 256]).flatten()
            
            red_hist /= red_hist.sum()
            green_hist /= green_hist.sum()  #color counts add up to 100%
            blue_hist /= blue_hist.sum()
            
            combined_histogram = [sum(x) for x in zip(red_hist, green_hist, blue_hist)]# Combine the color counts
            all_histograms.append(combined_histogram)
    
    # Save our color counts to a file
    csv_filename = os.path.join(output_folder, f'{output_folder}_histogram_frame_{frame_number}.csv')
    with open(csv_filename, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([f'Bin {i+1}' for i in range(bin_count)])  # Labels for the columns
        for hist in all_histograms:
            writer.writerow(hist)
    
    print(f"Saved our color data to {csv_filename}")
    
process_videos_in_folder(video_folder)
# Out:
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Chris_Benoit_waving_goodbye_wave_u_nm_np1_fr_med_1_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Chris_Benoit_waving_goodbye_wave_u_nm_np1_fr_med_1_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Chris_Benoit_waving_goodbye_wave_u_nm_np1_fr_med_1_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_7_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_7_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_7_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Hitch_Part_2_wave_h_nm_np1_fr_goo_12_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Hitch_Part_2_wave_h_nm_np1_fr_goo_12_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Hitch_Part_2_wave_h_nm_np1_fr_goo_12_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Hitch_Part_1_wave_u_nm_np1_fr_goo_1_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Hitch_Part_1_wave_u_nm_np1_fr_goo_1_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Hitch_Part_1_wave_u_nm_np1_fr_goo_1_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/A_Beautiful_Mind_2_wave_u_cm_np1_ri_med_3_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/A_Beautiful_Mind_2_wave_u_cm_np1_ri_med_3_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/A_Beautiful_Mind_2_wave_u_cm_np1_ri_med_3_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/prelinger_LetsBeGo1953_wave_u_cm_np10_ba_med_2_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/prelinger_LetsBeGo1953_wave_u_cm_np10_ba_med_2_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/prelinger_LetsBeGo1953_wave_u_cm_np10_ba_med_2_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_u_nm_np1_fr_med_34_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_u_nm_np1_fr_med_34_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_u_nm_np1_fr_med_34_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_f_nm_np1_fr_med_21_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_f_nm_np1_fr_med_21_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_f_nm_np1_fr_med_21_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Abschieds-winken_!!!!!!_Gruss_Guido_wave_u_cm_np1_fr_bad_1_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Abschieds-winken_!!!!!!_Gruss_Guido_wave_u_cm_np1_fr_bad_1_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Abschieds-winken_!!!!!!_Gruss_Guido_wave_u_cm_np1_fr_bad_1_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/L_cheln_Und_Winken_wave_h_cm_np1_fr_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/L_cheln_Und_Winken_wave_h_cm_np1_fr_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/L_cheln_Und_Winken_wave_h_cm_np1_fr_med_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BIG_FISH_wave_u_nm_np1_le_goo_28_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BIG_FISH_wave_u_nm_np1_le_goo_28_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BIG_FISH_wave_u_nm_np1_le_goo_28_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_1_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_1_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_1_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bubble_Gum_Club_2_wave_h_nm_np2_fr_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bubble_Gum_Club_2_wave_h_nm_np2_fr_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bubble_Gum_Club_2_wave_h_nm_np2_fr_med_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/likebeckam_wave_u_cm_np1_le_med_20_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/likebeckam_wave_u_cm_np1_le_med_20_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/likebeckam_wave_u_cm_np1_le_med_20_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/winKen_wave_u_cm_np1_ba_bad_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/winKen_wave_u_cm_np1_ba_bad_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/winKen_wave_u_cm_np1_ba_bad_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_10_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_10_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_10_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/IndianaJonesandTheTempleofDoom_wave_h_nm_np1_fr_med_2_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/IndianaJonesandTheTempleofDoom_wave_h_nm_np1_fr_med_2_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/IndianaJonesandTheTempleofDoom_wave_h_nm_np1_fr_med_2_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/OldSchool_wave_u_nm_np1_fr_med_24_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/OldSchool_wave_u_nm_np1_fr_med_24_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/OldSchool_wave_u_nm_np1_fr_med_24_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/DONNIE_DARKO_wave_u_nm_np1_le_goo_8_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/DONNIE_DARKO_wave_u_nm_np1_le_goo_8_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/DONNIE_DARKO_wave_u_nm_np1_le_goo_8_output_histogram_frame_3.csv
# UnicodeDecodeError: Skipping file Target_video/Wave/Newall_Green_High_Students_Waving_Goodbye_wave_u_cm_np1_fr_med_0.avi. Error: 'utf-8' codec can't decode byte 0x8c in position 65: invalid start byte
# Skipping Target_video/Wave/Newall_Green_High_Students_Waving_Goodbye_wave_u_cm_np1_fr_med_0.avi due to extraction failure.
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/likebeckam_wave_u_cm_np1_fr_med_6_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/likebeckam_wave_u_cm_np1_fr_med_6_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/likebeckam_wave_u_cm_np1_fr_med_6_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Pirates_5_wave_h_nm_np1_fr_med_8_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Pirates_5_wave_h_nm_np1_fr_med_8_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Pirates_5_wave_h_nm_np1_fr_med_8_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_u_nm_np1_fr_med_27_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_u_nm_np1_fr_med_27_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_u_nm_np1_fr_med_27_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Miro_Klose_winkt_wave_f_cm_np1_le_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Miro_Klose_winkt_wave_f_cm_np1_le_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Miro_Klose_winkt_wave_f_cm_np1_le_med_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/We_Wave_-_Premiere_wave_f_cm_np2_fr_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/We_Wave_-_Premiere_wave_f_cm_np2_fr_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/We_Wave_-_Premiere_wave_f_cm_np2_fr_med_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Poldi_beim_Spiel_Deutschland_Schweden_16_8_wave_u_cm_np1_ri_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Poldi_beim_Spiel_Deutschland_Schweden_16_8_wave_u_cm_np1_ri_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Poldi_beim_Spiel_Deutschland_Schweden_16_8_wave_u_cm_np1_ri_med_0_output_histogram_frame_3.csv
# UnicodeDecodeError: Skipping file Target_video/Wave/Newall_Green_High_Students_Waving_Goodbye_wave_u_cm_np1_fr_bad_2.avi. Error: 'utf-8' codec can't decode byte 0x8c in position 65: invalid start byte
# Skipping Target_video/Wave/Newall_Green_High_Students_Waving_Goodbye_wave_u_cm_np1_fr_bad_2.avi due to extraction failure.
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/50_FIRST_DATES_wave_u_cm_np1_fr_med_1_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/50_FIRST_DATES_wave_u_cm_np1_fr_med_1_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/50_FIRST_DATES_wave_u_cm_np1_fr_med_1_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/WeddingCrashers_wave_u_nm_np1_fr_goo_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/WeddingCrashers_wave_u_nm_np1_fr_goo_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/WeddingCrashers_wave_u_nm_np1_fr_goo_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/UNREPEATABLE_wave_f_nm_np1_fr_med_5_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/UNREPEATABLE_wave_f_nm_np1_fr_med_5_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/UNREPEATABLE_wave_f_nm_np1_fr_med_5_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BATMAN_BEGINS_wave_u_cm_np1_fr_med_19_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BATMAN_BEGINS_wave_u_cm_np1_fr_med_19_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BATMAN_BEGINS_wave_u_cm_np1_fr_med_19_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/AmericanGangster_wave_u_cm_np1_fr_med_57_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/AmericanGangster_wave_u_cm_np1_fr_med_57_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/AmericanGangster_wave_u_cm_np1_fr_med_57_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/veoh_harold_and_kumar_wave_u_nm_np1_fr_goo_5_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/veoh_harold_and_kumar_wave_u_nm_np1_fr_goo_5_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/veoh_harold_and_kumar_wave_u_nm_np1_fr_goo_5_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_u_cm_np1_fr_med_6_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_u_cm_np1_fr_med_6_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_u_cm_np1_fr_med_6_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/50_FIRST_DATES_wave_u_cm_np1_fr_goo_30_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/50_FIRST_DATES_wave_u_cm_np1_fr_goo_30_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/50_FIRST_DATES_wave_u_cm_np1_fr_goo_30_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/EVOLUTION_wave_u_nm_np1_le_med_3_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/EVOLUTION_wave_u_nm_np1_le_med_3_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/EVOLUTION_wave_u_nm_np1_le_med_3_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BIG_FISH_wave_u_nm_np1_fr_bad_4_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BIG_FISH_wave_u_nm_np1_fr_bad_4_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BIG_FISH_wave_u_nm_np1_fr_bad_4_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Eurotrip_wave_u_nm_np1_fr_goo_4_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Eurotrip_wave_u_nm_np1_fr_goo_4_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Eurotrip_wave_u_nm_np1_fr_goo_4_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/CharlieAndTheChocolateFactory_wave_u_nm_np2_fr_goo_18_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/CharlieAndTheChocolateFactory_wave_u_nm_np2_fr_goo_18_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/CharlieAndTheChocolateFactory_wave_u_nm_np2_fr_goo_18_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_le_med_6_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_le_med_6_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_le_med_6_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/21_wave_u_nm_np1_fr_goo_5_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/21_wave_u_nm_np1_fr_goo_5_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/21_wave_u_nm_np1_fr_goo_5_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_5_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_5_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_5_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/prideandprejudice1_wave_f_nm_np1_ri_med_14_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/prideandprejudice1_wave_f_nm_np1_ri_med_14_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/prideandprejudice1_wave_f_nm_np1_ri_med_14_output_histogram_frame_3.csv
# UnicodeDecodeError: Skipping file Target_video/Wave/Wie_man_winkt!!_wave_u_cm_np1_fr_med_0.avi. Error: 'utf-8' codec can't decode byte 0x8c in position 65: invalid start byte
# Skipping Target_video/Wave/Wie_man_winkt!!_wave_u_cm_np1_fr_med_0.avi due to extraction failure.
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/TrumanShow_wave_u_nm_np1_fr_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/TrumanShow_wave_u_nm_np1_fr_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/TrumanShow_wave_u_nm_np1_fr_med_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/MUSE_Wave_Goodbye_in_Wembley_wave_u_cm_np3_fr_med_1_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/MUSE_Wave_Goodbye_in_Wembley_wave_u_cm_np3_fr_med_1_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/MUSE_Wave_Goodbye_in_Wembley_wave_u_cm_np3_fr_med_1_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/MUSE_Wave_Goodbye_in_Wembley_wave_u_nm_np3_fr_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/MUSE_Wave_Goodbye_in_Wembley_wave_u_nm_np3_fr_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/MUSE_Wave_Goodbye_in_Wembley_wave_u_nm_np3_fr_med_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_9_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_9_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_9_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Maddin_winkt_wave_h_cm_np1_le_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Maddin_winkt_wave_h_cm_np1_le_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Maddin_winkt_wave_h_cm_np1_le_med_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/HP_PRISONER_OF_AZKABAN_wave_f_cm_np1_fr_med_12_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/HP_PRISONER_OF_AZKABAN_wave_f_cm_np1_fr_med_12_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/HP_PRISONER_OF_AZKABAN_wave_f_cm_np1_fr_med_12_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/TrumanShow_wave_f_nm_np1_fr_med_26_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/TrumanShow_wave_f_nm_np1_fr_med_26_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/TrumanShow_wave_f_nm_np1_fr_med_26_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Chris_Benoit_waving_goodbye_wave_u_nm_np1_fr_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Chris_Benoit_waving_goodbye_wave_u_nm_np1_fr_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Chris_Benoit_waving_goodbye_wave_u_nm_np1_fr_med_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Gaye_waves_to_the_paparazzi_as_she_flees_New_York_after_stalking_Adam_Lambert_in_Central_Park_wave_u_cm_np1_fr_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Gaye_waves_to_the_paparazzi_as_she_flees_New_York_after_stalking_Adam_Lambert_in_Central_Park_wave_u_cm_np1_fr_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Gaye_waves_to_the_paparazzi_as_she_flees_New_York_after_stalking_Adam_Lambert_in_Central_Park_wave_u_cm_np1_fr_med_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/_I_ll_Just_Wave_My_Hand__sung_by_Cornerstone_Male_Choir_wave_u_cm_np1_fr_med_2_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/_I_ll_Just_Wave_My_Hand__sung_by_Cornerstone_Male_Choir_wave_u_cm_np1_fr_med_2_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/_I_ll_Just_Wave_My_Hand__sung_by_Cornerstone_Male_Choir_wave_u_cm_np1_fr_med_2_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BuddhaPainter_wave_u_nm_np1_fr_med_1_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BuddhaPainter_wave_u_nm_np1_fr_med_1_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BuddhaPainter_wave_u_nm_np1_fr_med_1_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/EVOLUTION_wave_u_nm_np1_fr_med_18_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/EVOLUTION_wave_u_nm_np1_fr_med_18_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/EVOLUTION_wave_u_nm_np1_fr_med_18_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/prelinger_LetsBeGo1953_wave_u_cm_np10_ba_med_3_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/prelinger_LetsBeGo1953_wave_u_cm_np10_ba_med_3_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/prelinger_LetsBeGo1953_wave_u_cm_np10_ba_med_3_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/DONNIE_DARKO_wave_u_nm_np1_fr_goo_9_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/DONNIE_DARKO_wave_u_nm_np1_fr_goo_9_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/DONNIE_DARKO_wave_u_nm_np1_fr_goo_9_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BLACK_HAWK_DOWN_wave_u_nm_np1_ba_goo_19_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BLACK_HAWK_DOWN_wave_u_nm_np1_ba_goo_19_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BLACK_HAWK_DOWN_wave_u_nm_np1_ba_goo_19_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Maya_beim_Winken_wave_f_cm_np1_fr_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Maya_beim_Winken_wave_f_cm_np1_fr_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Maya_beim_Winken_wave_f_cm_np1_fr_med_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_f_nm_np1_fr_goo_37_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_f_nm_np1_fr_goo_37_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_f_nm_np1_fr_goo_37_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/CastAway1_wave_u_cm_np1_ri_med_4_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/CastAway1_wave_u_cm_np1_ri_med_4_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/CastAway1_wave_u_cm_np1_ri_med_4_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Maddin_winkt_wave_h_cm_np1_fr_med_1_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Maddin_winkt_wave_h_cm_np1_fr_med_1_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Maddin_winkt_wave_h_cm_np1_fr_med_1_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Superbad_wave_f_cm_np1_fr_med_4_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Superbad_wave_f_cm_np1_fr_med_4_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Superbad_wave_f_cm_np1_fr_med_4_output_histogram_frame_3.csv
# UnicodeDecodeError: Skipping file Target_video/Wave/Newall_Green_High_Students_Waving_Goodbye_wave_u_cm_np3_fr_med_1.avi. Error: 'utf-8' codec can't decode byte 0x8c in position 65: invalid start byte
# Skipping Target_video/Wave/Newall_Green_High_Students_Waving_Goodbye_wave_u_cm_np3_fr_med_1.avi due to extraction failure.
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/wave_and_say_hi_wave_u_nm_np1_fr_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/wave_and_say_hi_wave_u_nm_np1_fr_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/wave_and_say_hi_wave_u_nm_np1_fr_med_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/TrumanShow_wave_u_nm_np1_fr_med_25_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/TrumanShow_wave_u_nm_np1_fr_med_25_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/TrumanShow_wave_u_nm_np1_fr_med_25_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/IamLegend_wave_u_nm_np1_ba_med_6_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/IamLegend_wave_u_nm_np1_ba_med_6_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/IamLegend_wave_u_nm_np1_ba_med_6_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/50_FIRST_DATES_wave_f_cm_np1_fr_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/50_FIRST_DATES_wave_f_cm_np1_fr_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/50_FIRST_DATES_wave_f_cm_np1_fr_med_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BIG_FISH_wave_u_nm_np1_fr_goo_10_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BIG_FISH_wave_u_nm_np1_fr_goo_10_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BIG_FISH_wave_u_nm_np1_fr_goo_10_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/AllThePresidentMen_wave_h_nm_np1_fr_med_6_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/AllThePresidentMen_wave_h_nm_np1_fr_med_6_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/AllThePresidentMen_wave_h_nm_np1_fr_med_6_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/eddieizzardcircle_wave_u_nm_np1_ri_med_8_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/eddieizzardcircle_wave_u_nm_np1_ri_med_8_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/eddieizzardcircle_wave_u_nm_np1_ri_med_8_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/_I_ll_Just_Wave_My_Hand__sung_by_Cornerstone_Male_Choir_wave_u_cm_np1_fr_med_1_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/_I_ll_Just_Wave_My_Hand__sung_by_Cornerstone_Male_Choir_wave_u_cm_np1_fr_med_1_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/_I_ll_Just_Wave_My_Hand__sung_by_Cornerstone_Male_Choir_wave_u_cm_np1_fr_med_1_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Abschieds-winken_!!!!!!_Gruss_Guido_wave_u_cm_np1_fr_bad_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Abschieds-winken_!!!!!!_Gruss_Guido_wave_u_cm_np1_fr_bad_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Abschieds-winken_!!!!!!_Gruss_Guido_wave_u_cm_np1_fr_bad_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/_I_ll_Just_Wave_My_Hand__sung_by_Cornerstone_Male_Choir_wave_u_cm_np1_fr_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/_I_ll_Just_Wave_My_Hand__sung_by_Cornerstone_Male_Choir_wave_u_cm_np1_fr_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/_I_ll_Just_Wave_My_Hand__sung_by_Cornerstone_Male_Choir_wave_u_cm_np1_fr_med_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/EVOLUTION_wave_u_cm_np1_fr_med_4_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/EVOLUTION_wave_u_cm_np1_fr_med_4_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/EVOLUTION_wave_u_cm_np1_fr_med_4_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/winKen_wave_u_cm_np1_ri_bad_1_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/winKen_wave_u_cm_np1_ri_bad_1_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/winKen_wave_u_cm_np1_ri_bad_1_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_3_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_3_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_3_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/HP_PRISONER_OF_AZKABAN_wave_u_nm_np1_ri_med_39_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/HP_PRISONER_OF_AZKABAN_wave_u_nm_np1_ri_med_39_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/HP_PRISONER_OF_AZKABAN_wave_u_nm_np1_ri_med_39_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Glory_wave_u_nm_np6_fr_med_33_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Glory_wave_u_nm_np6_fr_med_33_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Glory_wave_u_nm_np6_fr_med_33_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/KUNG_FU_HUSTLE_wave_f_nm_np1_fr_med_7_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/KUNG_FU_HUSTLE_wave_f_nm_np1_fr_med_7_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/KUNG_FU_HUSTLE_wave_f_nm_np1_fr_med_7_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Song_I_Can_Wave_My_Hands_-_Cullen_s_Abc_s_wave_u_cm_np1_fr_med_1_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Song_I_Can_Wave_My_Hands_-_Cullen_s_Abc_s_wave_u_cm_np1_fr_med_1_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Song_I_Can_Wave_My_Hands_-_Cullen_s_Abc_s_wave_u_cm_np1_fr_med_1_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/American_History_X_wave_u_nm_np1_fr_med_16_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/American_History_X_wave_u_nm_np1_fr_med_16_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/American_History_X_wave_u_nm_np1_fr_med_16_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Maya_beim_Winken_wave_f_cm_np1_fr_med_2_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Maya_beim_Winken_wave_f_cm_np1_fr_med_2_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Maya_beim_Winken_wave_f_cm_np1_fr_med_2_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_2_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_2_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_2_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Maya_beim_Winken_wave_f_cm_np1_fr_med_1_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Maya_beim_Winken_wave_f_cm_np1_fr_med_1_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Maya_beim_Winken_wave_f_cm_np1_fr_med_1_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Song_I_Can_Wave_My_Hands_-_Cullen_s_Abc_s_wave_u_cm_np1_fr_med_2_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Song_I_Can_Wave_My_Hands_-_Cullen_s_Abc_s_wave_u_cm_np1_fr_med_2_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Song_I_Can_Wave_My_Hands_-_Cullen_s_Abc_s_wave_u_cm_np1_fr_med_2_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_u_nm_np1_fr_med_9_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_u_nm_np1_fr_med_9_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_u_nm_np1_fr_med_9_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Song_I_Can_Wave_My_Hands_-_Cullen_s_Abc_s_wave_u_cm_np1_fr_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Song_I_Can_Wave_My_Hands_-_Cullen_s_Abc_s_wave_u_cm_np1_fr_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Song_I_Can_Wave_My_Hands_-_Cullen_s_Abc_s_wave_u_cm_np1_fr_med_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/L_cheln_Und_Winken_wave_h_cm_np1_fr_med_1_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/L_cheln_Und_Winken_wave_h_cm_np1_fr_med_1_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/L_cheln_Und_Winken_wave_h_cm_np1_fr_med_1_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Oceans12_wave_h_nm_np1_fr_goo_8_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Oceans12_wave_h_nm_np1_fr_goo_8_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Oceans12_wave_h_nm_np1_fr_goo_8_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Crash_wave_u_cm_np1_ba_med_13_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Crash_wave_u_cm_np1_ba_med_13_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Crash_wave_u_cm_np1_ba_med_13_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/20060723sfjffbartsinger_wave_f_cm_np1_ba_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/20060723sfjffbartsinger_wave_f_cm_np1_ba_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/20060723sfjffbartsinger_wave_f_cm_np1_ba_med_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/CharlieAndTheChocolateFactory_wave_u_nm_np1_fr_bad_1_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/CharlieAndTheChocolateFactory_wave_u_nm_np1_fr_bad_1_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/CharlieAndTheChocolateFactory_wave_u_nm_np1_fr_bad_1_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BIG_FISH_wave_u_nm_np1_fr_goo_9_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BIG_FISH_wave_u_nm_np1_fr_goo_9_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/BIG_FISH_wave_u_nm_np1_fr_goo_9_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_8_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_8_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_8_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_f_nm_np1_ri_med_10_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_f_nm_np1_ri_med_10_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/RATRACE_wave_f_nm_np1_ri_med_10_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Hands_Up__Clap_Hands_And_Wave!_wave_f_cm_np1_ri_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Hands_Up__Clap_Hands_And_Wave!_wave_f_cm_np1_ri_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Hands_Up__Clap_Hands_And_Wave!_wave_f_cm_np1_ri_med_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/SchoolRulesHowTheyHelpUs_wave_f_nm_np1_ba_med_0_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/SchoolRulesHowTheyHelpUs_wave_f_nm_np1_ba_med_0_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/SchoolRulesHowTheyHelpUs_wave_f_nm_np1_ba_med_0_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/CharlieAndTheChocolateFactory_wave_u_nm_np1_fr_med_2_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/CharlieAndTheChocolateFactory_wave_u_nm_np1_fr_med_2_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/CharlieAndTheChocolateFactory_wave_u_nm_np1_fr_med_2_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/OldSchool_wave_f_cm_np1_fr_med_13_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/OldSchool_wave_f_cm_np1_fr_med_13_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/OldSchool_wave_f_cm_np1_fr_med_13_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/50_FIRST_DATES_wave_u_cm_np1_fr_med_36_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/50_FIRST_DATES_wave_u_cm_np1_fr_med_36_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/50_FIRST_DATES_wave_u_cm_np1_fr_med_36_output_histogram_frame_3.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_4_output_histogram_frame_1.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_4_output_histogram_frame_2.csv
# Histogram vectors saved to /home/vdixit5/Desktop/MWD project files/Target_video/Wave_output/Bush_Wave_vs__Obama_Wave_and_Which_Commander-in-chief_Salutes_the_Best__You_Decide_wave_u_cm_np1_fr_med_4_output_histogram_frame_3.csv
